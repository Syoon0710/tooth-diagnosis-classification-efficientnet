# %%
# !pip install efficientnet_pytorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting efficientnet_pytorch
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet_pytorch) (1.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet_pytorch) (4.1.1)
# Building wheels for collected packages: efficientnet-pytorch
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16446 sha256=11d4784525c46ce84e9abeaa6fedd5fe74444245811cf7f94bcc3e28e4a33152
#   Stored in directory: /root/.cache/pip/wheels/0e/cc/b2/49e74588263573ff778da58cc99b9c6349b496636a7e165be6
# Successfully built efficientnet-pytorch
# Installing collected packages: efficientnet-pytorch
# Successfully installed efficientnet-pytorch-0.7.1

# %%
from efficientnet_pytorch import EfficientNet
model = EfficientNet.from_pretrained('efficientnet-b0')
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b0-355c32eb.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b0-355c32eb.pth
#   0%|          | 0.00/20.4M [00:00<?, ?B/s]
# Loaded pretrained weights for efficientnet-b0

# %%
## 학습 코드
import numpy as np
import json
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import random

from efficientnet_pytorch import EfficientNet
model_name = 'efficientnet-b0'  # b5

image_size = EfficientNet.get_image_size(model_name)
print(image_size)
model = EfficientNet.from_pretrained(model_name, num_classes=2)
# Out:
# 224
# Loaded pretrained weights for efficientnet-b0

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")  # set gpu

model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(model.parameters(), 
                         lr = 0.05,
                         momentum=0.9,
                         weight_decay=1e-4)

lmbda = lambda epoch: 0.98739
exp_lr_scheduler = optim.lr_scheduler.MultiplicativeLR(optimizer_ft, lr_lambda=lmbda)

# %%
for n, p in model.named_parameters():
    if '_fc' not in n and '_conv_head' not in n and '_blocks.15' not in n:
        p.requires_grad = False
for p in model._bn1.parameters():
    p.requires_grad = True
# model = torch.nn.parallel.DistributedDataParallel(model)

# %%
## 데이타 로드!!
batch_size  = 128
random_seed = 555
random.seed(random_seed)
torch.manual_seed(random_seed)

# %%
# test 파일들을 나중에 제출 해야 하기 때문에 미리 split 해놓고 나눠서 데이터셋을 만듬
from torchvision import transforms, datasets
data_path = '/content/drive/MyDrive/dataset'  # class 별 폴더로 나누어진걸 확 가져와서 라벨도 달아준다
train_dataset = datasets.ImageFolder(
                                f"{data_path}/train",
                                transforms.Compose([
                                    transforms.RandomHorizontalFlip(),
                                    transforms.Resize((224, 224)),
                                    transforms.ToTensor(),
                                    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
                                ]))

# %%
val_dataset = datasets.ImageFolder(
                                f"{data_path}/val",
                                transforms.Compose([
                                    transforms.Resize((224, 224)),
                                    transforms.ToTensor(),
                                    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
                                ]))

# %%
test_dataset = datasets.ImageFolder(
                                f"{data_path}/test",
                                transforms.Compose([
                                    transforms.Resize((224, 224)),
                                    transforms.ToTensor(),
                                    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
                                ]))

# %%
## data loader 선언
dataloaders, batch_num = {}, {}
dataloaders['train'] = torch.utils.data.DataLoader(train_dataset,
                                              batch_size=batch_size, shuffle=True)
dataloaders['valid'] = torch.utils.data.DataLoader(val_dataset,
                                              batch_size=batch_size, shuffle=False)
dataloaders['test']  = torch.utils.data.DataLoader(test_dataset,
                                              batch_size=batch_size, shuffle=False)
batch_num['train'], batch_num['valid'], batch_num['test'] = len(dataloaders['train']), len(dataloaders['valid']), len(dataloaders['test'])
print('batch_size : %d,  tvt : %d / %d / %d' % (batch_size, batch_num['train'], batch_num['valid'], batch_num['test']))
# Out:
# batch_size : 128,  tvt : 13 / 2 / 2

# %%
## 데이타 체크
import torchvision
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

num_show_img = 2

class_names = {
    "0": "Abrasion",      # "0": "충치"
    "1": "Normal",   # "1": "정상"
}


# train check
inputs, classes = next(iter(dataloaders['train']))
out = torchvision.utils.make_grid(inputs[:num_show_img])  # batch의 이미지를 오려부친다
imshow(out, title=[class_names[str(int(x))] for x in classes[:num_show_img]])
# valid check
inputs, classes = next(iter(dataloaders['valid']))
out = torchvision.utils.make_grid(inputs[:num_show_img])  # batch의 이미지를 오려부친다
imshow(out, title=[class_names[str(int(x))] for x in classes[:num_show_img]])
# test check
inputs, classes = next(iter(dataloaders['test']))
out = torchvision.utils.make_grid(inputs[:num_show_img])  # batch의 이미지를 오려부친다
imshow(out, title=[class_names[str(int(x))] for x in classes[:num_show_img]])

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    train_loss, train_acc, valid_loss, valid_acc = [], [], [], []
    
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss, running_corrects, num_cnt = 0.0, 0, 0
            
            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                num_cnt += len(labels)
            if phase == 'train':
                scheduler.step()
            
            epoch_loss = float(running_loss / num_cnt)
            epoch_acc  = float((running_corrects.double() / num_cnt).cpu()*100)
            
            if phase == 'train':
                train_loss.append(epoch_loss)
                train_acc.append(epoch_acc)
            else:
                valid_loss.append(epoch_loss)
                valid_acc.append(epoch_acc)
            print('{} Loss: {:.2f} Acc: {:.1f}'.format(phase, epoch_loss, epoch_acc))
           
            # deep copy the model
            if phase == 'valid' and epoch_acc > best_acc:
                best_idx = epoch
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
#                 best_model_wts = copy.deepcopy(model.module.state_dict())
                print('==> best model saved - %d / %.1f'%(best_idx, best_acc))

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best valid Acc: %d - %.1f' %(best_idx, best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    # torch.save(model.state_dict(), 'new_tooth_classification_b0.pt')
    torch.save(model, 'diagnoisis_classification_b0.pt')
    print('model saved')
    return model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc

# %%
model, best_idx, best_acc, train_loss, train_acc, valid_loss, valid_acc = train_model(model, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=300)
# Out:
# Epoch 0/299
# ----------
# train Loss: 0.65 Acc: 61.5
# valid Loss: 0.69 Acc: 52.0
# ==> best model saved - 0 / 52.0
# Epoch 1/299
# ----------
# train Loss: 0.53 Acc: 74.6
# valid Loss: 0.62 Acc: 64.0
# ==> best model saved - 1 / 64.0
# Epoch 2/299
# ----------
# train Loss: 0.42 Acc: 80.6
# valid Loss: 0.65 Acc: 65.0
# ==> best model saved - 2 / 65.0
# Epoch 3/299
# ----------
# train Loss: 0.35 Acc: 85.3
# valid Loss: 0.60 Acc: 71.5
# ==> best model saved - 3 / 71.5
# Epoch 4/299
# ----------
# train Loss: 0.29 Acc: 88.0
# valid Loss: 0.79 Acc: 59.5
# Epoch 5/299
# ----------
# train Loss: 0.23 Acc: 91.4
# valid Loss: 0.79 Acc: 58.5
# Epoch 6/299
# ----------
# train Loss: 0.17 Acc: 93.5
# valid Loss: 1.22 Acc: 54.0
# Epoch 7/299
# ----------
# train Loss: 0.14 Acc: 94.9
# valid Loss: 1.21 Acc: 55.0
# Epoch 8/299
# ----------
# train Loss: 0.13 Acc: 95.5
# valid Loss: 1.17 Acc: 56.0
# Epoch 9/299
# ----------
# train Loss: 0.11 Acc: 96.6
# valid Loss: 1.50 Acc: 54.0
# Epoch 10/299
# ----------
# train Loss: 0.10 Acc: 96.6
# valid Loss: 1.24 Acc: 60.0
# Epoch 11/299
# ----------
# train Loss: 0.09 Acc: 97.1
# valid Loss: 0.86 Acc: 66.5
# Epoch 12/299
# ----------
# train Loss: 0.06 Acc: 97.9
# valid Loss: 1.02 Acc: 64.5
# Epoch 13/299
# ----------
# train Loss: 0.06 Acc: 98.4
# valid Loss: 1.05 Acc: 63.0
# Epoch 14/299
# ----------
# train Loss: 0.05 Acc: 98.4
# valid Loss: 0.84 Acc: 66.0
# Epoch 15/299
# ----------
# train Loss: 0.05 Acc: 98.6
# valid Loss: 0.95 Acc: 64.5
# Epoch 16/299
# ----------
# train Loss: 0.04 Acc: 98.7
# valid Loss: 0.82 Acc: 68.5
# Epoch 17/299
# ----------
# train Loss: 0.05 Acc: 98.3
# valid Loss: 0.87 Acc: 69.5
# Epoch 18/299
# ----------
# train Loss: 0.04 Acc: 98.7
# valid Loss: 0.93 Acc: 69.0
# Epoch 19/299
# ----------
# train Loss: 0.04 Acc: 98.4
# valid Loss: 0.73 Acc: 72.0
# ==> best model saved - 19 / 72.0
# Epoch 20/299
# ----------
# train Loss: 0.03 Acc: 98.8
# valid Loss: 0.83 Acc: 70.0
# Epoch 21/299
# ----------
# train Loss: 0.03 Acc: 98.8
# valid Loss: 0.64 Acc: 76.0
# ==> best model saved - 21 / 76.0
# Epoch 22/299
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.62 Acc: 78.5
# ==> best model saved - 22 / 78.5
# Epoch 23/299
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.71 Acc: 76.5
# Epoch 24/299
# ----------
# train Loss: 0.04 Acc: 98.4
# valid Loss: 0.68 Acc: 80.5
# ==> best model saved - 24 / 80.5
# Epoch 25/299
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.64 Acc: 82.0
# ==> best model saved - 25 / 82.0
# Epoch 26/299
# ----------
# train Loss: 0.03 Acc: 99.3
# valid Loss: 0.69 Acc: 77.0
# Epoch 27/299
# ----------
# train Loss: 0.02 Acc: 99.2
# valid Loss: 0.71 Acc: 76.5
# Epoch 28/299
# ----------
# train Loss: 0.02 Acc: 99.4
# valid Loss: 0.71 Acc: 77.0
# Epoch 29/299
# ----------
# train Loss: 0.02 Acc: 99.4
# valid Loss: 0.69 Acc: 78.5
# Epoch 30/299
# ----------
# train Loss: 0.02 Acc: 99.4
# valid Loss: 0.66 Acc: 82.0
# Epoch 31/299
# ----------
# train Loss: 0.02 Acc: 99.4
# valid Loss: 0.68 Acc: 81.5
# Epoch 32/299
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 0.64 Acc: 80.0
# Epoch 33/299
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 0.58 Acc: 82.5
# ==> best model saved - 33 / 82.5
# Epoch 34/299
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 0.55 Acc: 83.0
# ==> best model saved - 34 / 83.0
# Epoch 35/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.56 Acc: 82.5
# Epoch 36/299
# ----------
# train Loss: 0.02 Acc: 99.4
# valid Loss: 0.54 Acc: 81.0
# Epoch 37/299
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 0.50 Acc: 84.0
# ==> best model saved - 37 / 84.0
# Epoch 38/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.45 Acc: 83.0
# Epoch 39/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.43 Acc: 84.5
# ==> best model saved - 39 / 84.5
# Epoch 40/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.41 Acc: 85.0
# ==> best model saved - 40 / 85.0
# Epoch 41/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.41 Acc: 85.5
# ==> best model saved - 41 / 85.5
# Epoch 42/299
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 0.47 Acc: 84.0
# Epoch 43/299
# ----------
# train Loss: 0.02 Acc: 99.4
# valid Loss: 0.47 Acc: 83.5
# Epoch 44/299
# ----------
# train Loss: 0.01 Acc: 99.4
# valid Loss: 0.48 Acc: 85.0
# Epoch 45/299
# ----------
# train Loss: 0.02 Acc: 99.5
# valid Loss: 0.42 Acc: 84.5
# Epoch 46/299
# ----------
# train Loss: 0.02 Acc: 99.4
# valid Loss: 0.44 Acc: 85.5
# Epoch 47/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.40 Acc: 86.0
# ==> best model saved - 47 / 86.0
# Epoch 48/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.37 Acc: 85.5
# Epoch 49/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.34 Acc: 86.0
# Epoch 50/299
# ----------
# train Loss: 0.01 Acc: 99.5
# valid Loss: 0.34 Acc: 86.5
# ==> best model saved - 50 / 86.5
# Epoch 51/299
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 0.35 Acc: 87.0
# ==> best model saved - 51 / 87.0
# Epoch 52/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.32 Acc: 87.5
# ==> best model saved - 52 / 87.5
# Epoch 53/299
# ----------
# train Loss: 0.02 Acc: 99.3
# valid Loss: 0.25 Acc: 91.5
# ==> best model saved - 53 / 91.5
# Epoch 54/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.17 Acc: 93.5
# ==> best model saved - 54 / 93.5
# Epoch 55/299
# ----------
# train Loss: 0.01 Acc: 99.7
# valid Loss: 0.17 Acc: 93.0
# Epoch 56/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.17 Acc: 93.0
# Epoch 57/299
# ----------
# train Loss: 0.01 Acc: 99.7
# valid Loss: 0.16 Acc: 93.0
# Epoch 58/299
# ----------
# train Loss: 0.02 Acc: 99.4
# valid Loss: 0.17 Acc: 93.0
# Epoch 59/299
# ----------
# train Loss: 0.01 Acc: 99.5
# valid Loss: 0.16 Acc: 93.5
# Epoch 60/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.15 Acc: 94.5
# ==> best model saved - 60 / 94.5
# Epoch 61/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.15 Acc: 94.0
# Epoch 62/299
# ----------
# train Loss: 0.02 Acc: 99.4
# valid Loss: 0.16 Acc: 94.0
# Epoch 63/299
# ----------
# train Loss: 0.02 Acc: 99.4
# valid Loss: 0.17 Acc: 94.0
# Epoch 64/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.16 Acc: 94.5
# Epoch 65/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.16 Acc: 94.0
# Epoch 66/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.17 Acc: 94.0
# Epoch 67/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.17 Acc: 95.0
# ==> best model saved - 67 / 95.0
# Epoch 68/299
# ----------
# train Loss: 0.01 Acc: 99.7
# valid Loss: 0.19 Acc: 94.5
# Epoch 69/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.22 Acc: 92.5
# Epoch 70/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.22 Acc: 92.5
# Epoch 71/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.21 Acc: 93.0
# Epoch 72/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.19 Acc: 94.0
# Epoch 73/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.21 Acc: 93.0
# Epoch 74/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.20 Acc: 94.5
# Epoch 75/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.19 Acc: 94.0
# Epoch 76/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.17 Acc: 94.5
# Epoch 77/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.17 Acc: 94.5
# Epoch 78/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.18 Acc: 94.5
# Epoch 79/299
# ----------
# train Loss: 0.01 Acc: 99.7
# valid Loss: 0.19 Acc: 94.0
# Epoch 80/299
# ----------
# train Loss: 0.01 Acc: 99.5
# valid Loss: 0.19 Acc: 93.5
# Epoch 81/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.18 Acc: 93.5
# Epoch 82/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.18 Acc: 94.0
# Epoch 83/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.19 Acc: 94.0
# Epoch 84/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.20 Acc: 93.0
# Epoch 85/299
# ----------
# train Loss: 0.01 Acc: 99.4
# valid Loss: 0.20 Acc: 93.0
# Epoch 86/299
# ----------
# train Loss: 0.01 Acc: 99.7
# valid Loss: 0.20 Acc: 93.5
# Epoch 87/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.21 Acc: 93.5
# Epoch 88/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.21 Acc: 92.5
# Epoch 89/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.21 Acc: 92.5
# Epoch 90/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.18 Acc: 93.5
# Epoch 91/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.18 Acc: 93.5
# Epoch 92/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.19 Acc: 93.5
# Epoch 93/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.17 Acc: 94.0
# Epoch 94/299
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 0.17 Acc: 94.5
# Epoch 95/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.16 Acc: 95.5
# ==> best model saved - 95 / 95.5
# Epoch 96/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.16 Acc: 94.0
# Epoch 97/299
# ----------
# train Loss: 0.01 Acc: 99.7
# valid Loss: 0.17 Acc: 93.5
# Epoch 98/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.17 Acc: 95.0
# Epoch 99/299
# ----------
# train Loss: 0.01 Acc: 99.7
# valid Loss: 0.18 Acc: 94.0
# Epoch 100/299
# ----------
# train Loss: 0.02 Acc: 99.6
# valid Loss: 0.18 Acc: 94.5
# Epoch 101/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.20 Acc: 93.5
# Epoch 102/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.21 Acc: 93.0
# Epoch 103/299
# ----------
# train Loss: 0.01 Acc: 99.7
# valid Loss: 0.22 Acc: 92.5
# Epoch 104/299
# ----------
# train Loss: 0.01 Acc: 99.7
# valid Loss: 0.22 Acc: 92.5
# Epoch 105/299
# ----------
# train Loss: 0.01 Acc: 99.4
# valid Loss: 0.22 Acc: 92.5
# Epoch 106/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.20 Acc: 94.5
# Epoch 107/299
# ----------
# train Loss: 0.01 Acc: 99.7
# valid Loss: 0.21 Acc: 94.0
# Epoch 108/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.21 Acc: 94.0
# Epoch 109/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.23 Acc: 93.0
# Epoch 110/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.23 Acc: 93.0
# Epoch 111/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.22 Acc: 93.0
# Epoch 112/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.21 Acc: 93.5
# Epoch 113/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.21 Acc: 93.0
# Epoch 114/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.20 Acc: 93.0
# Epoch 115/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.19 Acc: 94.5
# Epoch 116/299
# ----------
# train Loss: 0.01 Acc: 99.7
# valid Loss: 0.18 Acc: 95.0
# Epoch 117/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.20 Acc: 93.5
# Epoch 118/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.20 Acc: 94.5
# Epoch 119/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.20 Acc: 94.0
# Epoch 120/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.21 Acc: 94.5
# Epoch 121/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.21 Acc: 94.5
# Epoch 122/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.20 Acc: 94.5
# Epoch 123/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 94.0
# Epoch 124/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.20 Acc: 93.5
# Epoch 125/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.19 Acc: 94.5
# Epoch 126/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.19 Acc: 94.0
# Epoch 127/299
# ----------
# train Loss: 0.01 Acc: 99.7
# valid Loss: 0.19 Acc: 94.5
# Epoch 128/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.18 Acc: 94.5
# Epoch 129/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.18 Acc: 94.5
# Epoch 130/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.17 Acc: 94.5
# Epoch 131/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.18 Acc: 94.5
# Epoch 132/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.18 Acc: 94.5
# Epoch 133/299
# ----------
# train Loss: 0.01 Acc: 99.7
# valid Loss: 0.18 Acc: 94.5
# Epoch 134/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.18 Acc: 94.5
# Epoch 135/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.18 Acc: 94.0
# Epoch 136/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.19 Acc: 94.0
# Epoch 137/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.19 Acc: 94.0
# Epoch 138/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.19 Acc: 93.0
# Epoch 139/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.19 Acc: 93.0
# Epoch 140/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.19 Acc: 93.0
# Epoch 141/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.19 Acc: 93.0
# Epoch 142/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 93.0
# Epoch 143/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.20 Acc: 92.5
# Epoch 144/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.21 Acc: 93.0
# Epoch 145/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.19 Acc: 93.0
# Epoch 146/299
# ----------
# train Loss: 0.01 Acc: 99.7
# valid Loss: 0.20 Acc: 92.5
# Epoch 147/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.22 Acc: 92.5
# Epoch 148/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.22 Acc: 93.0
# Epoch 149/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.22 Acc: 93.0
# Epoch 150/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.22 Acc: 93.0
# Epoch 151/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.22 Acc: 93.0
# Epoch 152/299
# ----------
# train Loss: 0.01 Acc: 99.5
# valid Loss: 0.21 Acc: 93.5
# Epoch 153/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.21 Acc: 93.5
# Epoch 154/299
# ----------
# train Loss: 0.00 Acc: 99.8
# valid Loss: 0.21 Acc: 93.5
# Epoch 155/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.21 Acc: 93.5
# Epoch 156/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.20 Acc: 93.5
# Epoch 157/299
# ----------
# train Loss: 0.01 Acc: 99.7
# valid Loss: 0.20 Acc: 94.0
# Epoch 158/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 93.5
# Epoch 159/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.21 Acc: 93.5
# Epoch 160/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 93.5
# Epoch 161/299
# ----------
# train Loss: 0.00 Acc: 100.0
# valid Loss: 0.19 Acc: 94.0
# Epoch 162/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.20 Acc: 94.5
# Epoch 163/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 94.5
# Epoch 164/299
# ----------
# train Loss: 0.01 Acc: 99.7
# valid Loss: 0.21 Acc: 94.0
# Epoch 165/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.21 Acc: 94.5
# Epoch 166/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.20 Acc: 95.0
# Epoch 167/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.19 Acc: 95.0
# Epoch 168/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.19 Acc: 94.5
# Epoch 169/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.19 Acc: 94.5
# Epoch 170/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.19 Acc: 94.5
# Epoch 171/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.19 Acc: 95.0
# Epoch 172/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.19 Acc: 94.5
# Epoch 173/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.20 Acc: 94.5
# Epoch 174/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.20 Acc: 94.5
# Epoch 175/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.20 Acc: 94.5
# Epoch 176/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 94.0
# Epoch 177/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.20 Acc: 94.0
# Epoch 178/299
# ----------
# train Loss: 0.00 Acc: 100.0
# valid Loss: 0.19 Acc: 94.5
# Epoch 179/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.19 Acc: 94.5
# Epoch 180/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.19 Acc: 95.0
# Epoch 181/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.19 Acc: 95.0
# Epoch 182/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.18 Acc: 94.5
# Epoch 183/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.19 Acc: 94.5
# Epoch 184/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.19 Acc: 94.5
# Epoch 185/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.19 Acc: 94.5
# Epoch 186/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.19 Acc: 94.5
# Epoch 187/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.19 Acc: 94.5
# Epoch 188/299
# ----------
# train Loss: 0.01 Acc: 99.7
# valid Loss: 0.20 Acc: 94.5
# Epoch 189/299
# ----------
# train Loss: 0.01 Acc: 99.7
# valid Loss: 0.20 Acc: 94.5
# Epoch 190/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.19 Acc: 94.5
# Epoch 191/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.19 Acc: 94.5
# Epoch 192/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.20 Acc: 94.5
# Epoch 193/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 94.5
# Epoch 194/299
# ----------
# train Loss: 0.00 Acc: 99.8
# valid Loss: 0.20 Acc: 94.5
# Epoch 195/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.20 Acc: 94.5
# Epoch 196/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.20 Acc: 94.5
# Epoch 197/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.21 Acc: 94.5
# Epoch 198/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.21 Acc: 94.0
# Epoch 199/299
# ----------
# train Loss: 0.01 Acc: 99.7
# valid Loss: 0.21 Acc: 94.0
# Epoch 200/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.21 Acc: 94.0
# Epoch 201/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.21 Acc: 94.0
# Epoch 202/299
# ----------
# train Loss: 0.01 Acc: 99.4
# valid Loss: 0.21 Acc: 94.0
# Epoch 203/299
# ----------
# train Loss: 0.01 Acc: 99.7
# valid Loss: 0.21 Acc: 94.0
# Epoch 204/299
# ----------
# train Loss: 0.00 Acc: 100.0
# valid Loss: 0.21 Acc: 94.0
# Epoch 205/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.21 Acc: 94.0
# Epoch 206/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.21 Acc: 94.0
# Epoch 207/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.21 Acc: 94.5
# Epoch 208/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.21 Acc: 94.5
# Epoch 209/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.20 Acc: 94.5
# Epoch 210/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 94.5
# Epoch 211/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.20 Acc: 95.0
# Epoch 212/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.20 Acc: 95.0
# Epoch 213/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.20 Acc: 95.0
# Epoch 214/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 95.0
# Epoch 215/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.20 Acc: 95.0
# Epoch 216/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 95.0
# Epoch 217/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.20 Acc: 95.0
# Epoch 218/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 95.0
# Epoch 219/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 95.0
# Epoch 220/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.20 Acc: 95.0
# Epoch 221/299
# ----------
# train Loss: 0.01 Acc: 99.7
# valid Loss: 0.20 Acc: 95.0
# Epoch 222/299
# ----------
# train Loss: 0.01 Acc: 100.0
# valid Loss: 0.20 Acc: 94.5
# Epoch 223/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 94.5
# Epoch 224/299
# ----------
# train Loss: 0.01 Acc: 99.7
# valid Loss: 0.20 Acc: 94.5
# Epoch 225/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.20 Acc: 94.0
# Epoch 226/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.20 Acc: 94.0
# Epoch 227/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.21 Acc: 94.0
# Epoch 228/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 94.5
# Epoch 229/299
# ----------
# train Loss: 0.00 Acc: 99.8
# valid Loss: 0.20 Acc: 94.5
# Epoch 230/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.20 Acc: 94.5
# Epoch 231/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.20 Acc: 94.5
# Epoch 232/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.20 Acc: 94.5
# Epoch 233/299
# ----------
# train Loss: 0.00 Acc: 99.8
# valid Loss: 0.20 Acc: 94.5
# Epoch 234/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 94.5
# Epoch 235/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.20 Acc: 94.5
# Epoch 236/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 94.5
# Epoch 237/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.19 Acc: 94.5
# Epoch 238/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.19 Acc: 94.5
# Epoch 239/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.19 Acc: 94.5
# Epoch 240/299
# ----------
# train Loss: 0.01 Acc: 99.7
# valid Loss: 0.19 Acc: 94.5
# Epoch 241/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.19 Acc: 94.0
# Epoch 242/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.19 Acc: 94.0
# Epoch 243/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.19 Acc: 94.0
# Epoch 244/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.19 Acc: 94.0
# Epoch 245/299
# ----------
# train Loss: 0.00 Acc: 100.0
# valid Loss: 0.19 Acc: 94.0
# Epoch 246/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.19 Acc: 94.0
# Epoch 247/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.19 Acc: 94.0
# Epoch 248/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.19 Acc: 94.0
# Epoch 249/299
# ----------
# train Loss: 0.00 Acc: 99.8
# valid Loss: 0.19 Acc: 94.0
# Epoch 250/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.19 Acc: 94.0
# Epoch 251/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 94.0
# Epoch 252/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 94.0
# Epoch 253/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 94.0
# Epoch 254/299
# ----------
# train Loss: 0.01 Acc: 99.7
# valid Loss: 0.20 Acc: 94.0
# Epoch 255/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 94.0
# Epoch 256/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.20 Acc: 94.0
# Epoch 257/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.20 Acc: 94.0
# Epoch 258/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 93.5
# Epoch 259/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.19 Acc: 93.5
# Epoch 260/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 93.0
# Epoch 261/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.20 Acc: 93.0
# Epoch 262/299
# ----------
# train Loss: 0.00 Acc: 99.8
# valid Loss: 0.19 Acc: 93.5
# Epoch 263/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.19 Acc: 93.5
# Epoch 264/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.19 Acc: 93.5
# Epoch 265/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.19 Acc: 93.5
# Epoch 266/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.19 Acc: 93.5
# Epoch 267/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.19 Acc: 94.0
# Epoch 268/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.19 Acc: 93.5
# Epoch 269/299
# ----------
# train Loss: 0.00 Acc: 99.8
# valid Loss: 0.19 Acc: 93.5
# Epoch 270/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.19 Acc: 93.5
# Epoch 271/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 93.5
# Epoch 272/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 93.5
# Epoch 273/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 93.5
# Epoch 274/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.20 Acc: 93.5
# Epoch 275/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.20 Acc: 93.5
# Epoch 276/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 93.5
# Epoch 277/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.19 Acc: 93.5
# Epoch 278/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.19 Acc: 93.5
# Epoch 279/299
# ----------
# train Loss: 0.01 Acc: 99.6
# valid Loss: 0.20 Acc: 93.5
# Epoch 280/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.20 Acc: 93.5
# Epoch 281/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.20 Acc: 93.5
# Epoch 282/299
# ----------
# train Loss: 0.00 Acc: 99.8
# valid Loss: 0.20 Acc: 93.5
# Epoch 283/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 93.5
# Epoch 284/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.20 Acc: 93.5
# Epoch 285/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.20 Acc: 93.5
# Epoch 286/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 93.5
# Epoch 287/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.20 Acc: 93.5
# Epoch 288/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.20 Acc: 93.5
# Epoch 289/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.20 Acc: 93.5
# Epoch 290/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 93.5
# Epoch 291/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.20 Acc: 93.5
# Epoch 292/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.19 Acc: 93.5
# Epoch 293/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.19 Acc: 93.5
# Epoch 294/299
# ----------
# train Loss: 0.00 Acc: 100.0
# valid Loss: 0.20 Acc: 93.5
# Epoch 295/299
# ----------
# train Loss: 0.00 Acc: 100.0
# valid Loss: 0.20 Acc: 93.5
# Epoch 296/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 93.5
# Epoch 297/299
# ----------
# train Loss: 0.01 Acc: 99.8
# valid Loss: 0.20 Acc: 93.5
# Epoch 298/299
# ----------
# train Loss: 0.00 Acc: 99.9
# valid Loss: 0.20 Acc: 93.5
# Epoch 299/299
# ----------
# train Loss: 0.01 Acc: 99.9
# valid Loss: 0.19 Acc: 94.0
# Training complete in 72m 0s
# Best valid Acc: 95 - 95.5
# model saved

# %%
## 결과 그래프 그리기
print('best model : %d - %1.f / %.1f'%(best_idx, valid_acc[best_idx], valid_loss[best_idx]))

fig, ax1 = plt.subplots()
ax1.plot(train_acc, 'b-')
ax1.plot(valid_acc, 'r-')
plt.plot(best_idx, valid_acc[best_idx], 'ro')
ax1.set_xlabel('epoch')

# Make the y-axis label, ticks and tick labels match the line color.

ax1.set_ylabel('acc', color='k')
ax1.tick_params('y', colors='k')

ax2 = ax1.twinx()
ax2.plot(train_loss, 'g-')
ax2.plot(valid_loss, 'k-')
plt.plot(best_idx, valid_loss[best_idx], 'ro')
ax2.set_ylabel('loss', color='k')
ax2.tick_params('y', colors='k')

fig.tight_layout()
plt.show()
# Out:
# best model : 95 - 96 / 0.2

# %%
def test_and_visualize_model(model, phase = 'test'):
    # phase = 'train', 'valid', 'test'
    
    was_training = model.training
    model.eval()
    # fig = plt.figure()
    
    running_loss, running_corrects, num_cnt = 0.0, 0, 0

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders[phase]):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)  # batch의 평균 loss 출력

            running_loss    += loss.item() * inputs.size(0)
            running_corrects+= torch.sum(preds == labels.data)
            num_cnt += inputs.size(0)  # batch size

    #         if i == 2: break

        test_loss = running_loss / num_cnt
        test_acc  = running_corrects.double() / num_cnt       
        print('test done : loss/acc : %.2f / %.1f' % (test_loss, test_acc*100))

    # 예시 그림 plot
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders[phase]):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)        

            # 예시 그림 plot
            for j in range(1, 30+1):
                ax = plt.subplot(30//2, 2, j)
                ax.axis('off')
                ax.set_title('%s : %s -> %s'%(
                    'True' if class_names[str(labels[j].cpu().numpy())]==class_names[str(preds[j].cpu().numpy())] else 'False',
                    class_names[str(labels[j].cpu().numpy())], class_names[str(preds[j].cpu().numpy())]))
                imshow(inputs.cpu().data[j])          
            if i == 0 : break


    model.train(mode=was_training);  # 다시 train모드로
  
# TEST!
test_and_visualize_model(model, phase = 'test')
# Out:
# test done : loss/acc : 0.10 / 96.5
